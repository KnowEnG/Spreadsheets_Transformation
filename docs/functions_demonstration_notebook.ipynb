# %%
# %%html
# <style>
# div.output_stderr{
#     display:none
# }
# </style>
# <a id='top'></a>
# # div.output_stderr{display:none}
# Out:
# <style>
# div.output_stderr{
#     display:none
# }
# </style>
# <a id='top'></a>
# # div.output_stderr{display:none}

# %% [markdown]
# # mini_pipelines_toolbox.py function Usage Examples.
# * Documentation for "../src/mini_pipelines_toolbox.py" function operation.
#
# ### Links:
# ##### (private) source repository:  https://github.com/dlanier/minipipelines.git
#
# ### Spreadsheet Transformations
# 1. [select_subtype_df](#select_subtype_df)
# 2. [common_samples_df](#common_samples_df)
# 3. [select_genes_df](#select_genes_df)
# 4. [merge_df](#merge_df)
# 5. [cluster_statistics_df](#cluster_statistics_df)
#
#
# ### Basic Transformations
# 1. [transpose_df](#transpose_df)
# 2. [abs_df](#abs_df)
# 3. [z_transform_df](#z_transform_df)
# 4. [log_transform_df](#log_transform_df)
# 5. [threshold_df](#threshold_df)
# 6. [stats_df](#stats_df)
#
#
# ### Utilities
# 1. [write_transform_df](#write_transform_df)
# 2. [get_outfile_name](#get_outfile_name)
# 3. [read_a_list_file](#read_a_list_file)

# %%
import os
import sys
import pandas as pd

sys.path.insert(1, '../src')
import mini_pipelines_toolbox as mpt

data_dir = '../data/spreadsheets'

results_dir = os.path.join(os.path.abspath('../test'), 'run_dir/results')
if not os.path.isdir(results_dir):
    print('Created witout overwrite:', results_dir)
    os.makedirs(results_dir)

# %%
#                    Display the content of the data directory
os.listdir(data_dir)
# Out:
# ['gene_samples_1.tsv',
#  'gene_samples_1_list.txt',
#  'gene_samples_small.tsv',
#  'gene_samples_small_labels.tsv',
#  'spreadsheet_A_.G.tsv',
#  'spreadsheet_B_.G.tsv',
#  'spreadsheet_One.txt',
#  'spreadsheet_Two.txt',
#  'tcga_ucec_somatic_mutation_data.df',
#  'transform_5_spreadsheet.tsv',
#  'UCEC_phenotype.txt']

# %% [markdown]
# # Spreadsheet Transformations

# %% [markdown]
# <a id="select_subtype_df"></a>

# %% [markdown]
# ### sub_df, phen_df = select_subtype_df(spread_df, pheno_df, phenotype_id, select_category) [[top]](#top)
# * spreadsheet_df is genes x samples.
# * phenotype_df is samples x phenotypes.
# * phenotype_id must exist as a column name in the phenotype_df.
# * and select_category must exist in the phenotype_id of that column.
# * "phen_df" has only the samples (rows) where "select_catagory" match
# * "sub_df" - the subtype dataframe will have only those samples (columns) where the category matched in the phenotpye.

# %%
spreadsheet_filename = 'tcga_ucec_somatic_mutation_data.df'
spreadsheet_filename = os.path.join(data_dir, spreadsheet_filename)
spreadsheet_df = pd.read_csv(spreadsheet_filename, sep='\t', index_col=0, header=0)
print(spreadsheet_df.head())
phenotype_filename = 'UCEC_phenotype.txt'
phenotype_filename = os.path.join(data_dir, phenotype_filename)
phenotype_df = pd.read_csv(phenotype_filename, sep='\t', index_col=0, header=0)
print(phenotype_df.head())
phenotype_id = 'grade'
select_category = 'grade 2'

sub_df, pheno_df = mpt.select_subtype_df(spreadsheet_df, phenotype_df, phenotype_id, select_category)
print(sub_df.head())
print(pheno_df.head())
# Out:
#                  TCGA-A5-A0G3  TCGA-A5-A0G5  TCGA-A5-A0G9  TCGA-A5-A0GA  \
# ENSG00000121410             0             0             0             0
# ENSG00000268895             0             0             0             0
# ENSG00000148584             0             0             0             0
# ENSG00000175899             0             0             0             0
# ENSG00000166535             0             0             1             0
#
#                  TCGA-A5-A0GB  TCGA-A5-A0GD  TCGA-A5-A0GE  TCGA-A5-A0GH  \
# ENSG00000121410             0             0             0             0
# ENSG00000268895             0             0             0             0
# ENSG00000148584             0             0             1             0
# ENSG00000175899             0             0             0             0
# ENSG00000166535             0             0             0             0
#
#                  TCGA-A5-A0GI  TCGA-A5-A0GJ      ...       TCGA-DI-A1NN  \
# ENSG00000121410             0             0      ...                  0
# ENSG00000268895             0             0      ...                  0
# ENSG00000148584             0             0      ...                  0
# ENSG00000175899             1             0      ...                  0
# ENSG00000166535             0             0      ...                  0
#
#                  TCGA-E6-A1LZ  TCGA-EO-A1Y5  TCGA-EO-A1Y8  TCGA-EY-A1GS  \
# ENSG00000121410             0             0             0             0
# ENSG00000268895             0             0             0             0
# ENSG00000148584             0             0             0             0
# ENSG00000175899             0             0             1             0
# ENSG00000166535             0             0             0             0
#
#                  TCGA-EY-A212  TCGA-FI-A2D2  TCGA-FI-A2EW  TCGA-FI-A2EX  \
# ENSG00000121410             0             0             0             0
# ENSG00000268895             0             0             0             0
# ENSG00000148584             0             0             0             0
# ENSG00000175899             0             0             0             0
# ENSG00000166535             0             0             0             0
#
#                  TCGA-FI-A2F8
# ENSG00000121410             0
# ENSG00000268895             0
# ENSG00000148584             0
# ENSG00000175899             0
# ENSG00000166535             0
#
# [5 rows x 248 columns]
#               days_to_death  days_to_last  days_survival  diag_age  \
# sample_id
# TCGA-A5-A0G1         3251.0           NaN         3251.0        67
# TCGA-A5-A0G2            NaN        4053.0         4053.0        57
# TCGA-A5-A0G3            NaN        1079.0         1079.0        61
# TCGA-A5-A0G5            NaN         790.0          790.0        73
# TCGA-A5-A0G9            NaN        2165.0         2165.0        79
#
#                                    race               ethnicity  gender  \
# sample_id
# TCGA-A5-A0G1                      white  not hispanic or latino  female
# TCGA-A5-A0G2                      asian  not hispanic or latino  female
# TCGA-A5-A0G3  black or african american                     NaN  female
# TCGA-A5-A0G5  black or african american                     NaN  female
# TCGA-A5-A0G9                      white                     NaN  female
#
#                 living histICDO3            hist_simple ICDO3site  ICD10  \
# sample_id
# TCGA-A5-A0G1  deceased    8441/3  serous adenocarcinoma     c54.1  c54.1
# TCGA-A5-A0G2    living    8441/3  serous adenocarcinoma     c54.1  c54.1
# TCGA-A5-A0G3    living    8441/3  serous adenocarcinoma     c54.1  c54.1
# TCGA-A5-A0G5    living    8310/3                  other     c54.1  c54.1
# TCGA-A5-A0G9    living    8380/3      endometrioid type     c54.1  c54.1
#
#               ICD10_simple        stage stage_simple  stage_ismeta    grade  \
# sample_id
# TCGA-A5-A0G1           1.0     stage ia            i             0  grade 3
# TCGA-A5-A0G2           1.0   stage iiib          iii             0  grade 3
# TCGA-A5-A0G3           1.0  stage iiic2          iii             0  grade 3
# TCGA-A5-A0G5           1.0     stage ib            i             0  grade 3
# TCGA-A5-A0G9           1.0     stage ib            i             0  grade 3
#
#              grade_simple residual
# sample_id
# TCGA-A5-A0G1   High Grade       r0
# TCGA-A5-A0G2   High Grade       r0
# TCGA-A5-A0G3   High Grade       r0
# TCGA-A5-A0G5   High Grade       r0
# TCGA-A5-A0G9   High Grade       r0
#                  TCGA-A5-A0GX  TCGA-BG-A186  TCGA-BS-A0TG  TCGA-BG-A0VT  \
# ENSG00000121410             0             0             0             0
# ENSG00000268895             0             0             0             0
# ENSG00000148584             0             0             0             0
# ENSG00000175899             0             0             0             0
# ENSG00000166535             0             0             0             0
#
#                  TCGA-D1-A16D  TCGA-BS-A0UT  TCGA-A5-A0VO  TCGA-AX-A063  \
# ENSG00000121410             0             0             0             0
# ENSG00000268895             0             0             0             0
# ENSG00000148584             0             0             0             0
# ENSG00000175899             0             0             0             0
# ENSG00000166535             0             0             0             0
#
#                  TCGA-A5-A0R7  TCGA-AP-A0LQ      ...       TCGA-B5-A11W  \
# ENSG00000121410             0             0      ...                  0
# ENSG00000268895             0             0      ...                  0
# ENSG00000148584             0             0      ...                  0
# ENSG00000175899             0             0      ...                  0
# ENSG00000166535             0             0      ...                  0
#
#                  TCGA-B5-A11J  TCGA-D1-A16J  TCGA-D1-A17Q  TCGA-AP-A0LT  \
# ENSG00000121410             0             0             1             0
# ENSG00000268895             0             0             0             0
# ENSG00000148584             0             0             1             0
# ENSG00000175899             0             0             0             0
# ENSG00000166535             0             0             1             0
#
#                  TCGA-BS-A0V8  TCGA-AX-A064  TCGA-D1-A16B  TCGA-BG-A18C  \
# ENSG00000121410             0             0             0             0
# ENSG00000268895             0             0             0             0
# ENSG00000148584             0             0             0             0
# ENSG00000175899             0             0             1             0
# ENSG00000166535             0             0             0             0
#
#                  TCGA-BS-A0WQ
# ENSG00000121410             0
# ENSG00000268895             0
# ENSG00000148584             0
# ENSG00000175899             0
# ENSG00000166535             0
#
# [5 rows x 75 columns]
#               days_to_death  days_to_last  days_survival  diag_age  \
# sample_id
# TCGA-A5-A0GD            NaN          97.0           97.0        75
# TCGA-A5-A0GE            NaN        2717.0         2717.0        38
# TCGA-A5-A0GI            NaN        1750.0         1750.0        63
# TCGA-A5-A0GJ            NaN        1447.0         1447.0        44
# TCGA-A5-A0GR            NaN         780.0          780.0        69
#
#                                    race               ethnicity  gender  \
# sample_id
# TCGA-A5-A0GD                      white                     NaN  female
# TCGA-A5-A0GE                      asian  not hispanic or latino  female
# TCGA-A5-A0GI                      white  not hispanic or latino  female
# TCGA-A5-A0GJ                      white  not hispanic or latino  female
# TCGA-A5-A0GR  black or african american  not hispanic or latino  female
#
#               living histICDO3        hist_simple ICDO3site  ICD10  \
# sample_id
# TCGA-A5-A0GD  living    8380/3  endometrioid type     c54.1  c54.1
# TCGA-A5-A0GE  living    8380/3  endometrioid type     c54.1  c54.1
# TCGA-A5-A0GI  living    8380/3  endometrioid type     c54.1  c54.1
# TCGA-A5-A0GJ  living    8380/3  endometrioid type     c54.1  c54.1
# TCGA-A5-A0GR  living    8380/3  endometrioid type     c54.1  c54.1
#
#               ICD10_simple     stage stage_simple  stage_ismeta    grade  \
# sample_id
# TCGA-A5-A0GD           1.0  stage ia            i             0  grade 2
# TCGA-A5-A0GE           1.0  stage ia            i             0  grade 2
# TCGA-A5-A0GI           1.0  stage ia            i             0  grade 2
# TCGA-A5-A0GJ           1.0  stage ia            i             0  grade 2
# TCGA-A5-A0GR           1.0  stage ia            i             0  grade 2
#
#                  grade_simple residual
# sample_id
# TCGA-A5-A0GD  Low grade (1,2)       r0
# TCGA-A5-A0GE  Low grade (1,2)       r0
# TCGA-A5-A0GI  Low grade (1,2)       r0
# TCGA-A5-A0GJ  Low grade (1,2)       r0
# TCGA-A5-A0GR  Low grade (1,2)       r0

# %% [markdown]
# <a id='common_samples_df'></a>

# %% [markdown]
# ### sp_1_df, sp_2_df = get_common_samples_df(spreadsheet_1_df, spreadsheet_2_df) [[top]](#top)

# %%
spreadsheet1_filename = 'spreadsheet_One.txt'
spreadsheet1_filename = os.path.join(data_dir, spreadsheet1_filename)
spreadsheet_1_df = pd.read_csv(spreadsheet1_filename, sep='\t', index_col=0, header=0)
print(spreadsheet_1_df.head())

spreadsheet2_filename = 'spreadsheet_Two.txt'
spreadsheet2_filename = os.path.join(data_dir, spreadsheet2_filename)
spreadsheet_2_df = pd.read_csv(spreadsheet2_filename, sep='\t', index_col=0, header=0)
print(spreadsheet_2_df.head())

sp_1_df, sp_2_df = mpt.common_samples_df(spreadsheet_1_df,spreadsheet_2_df)
print(sp_1_df.head())
print(sp_2_df.head())
# Out:
#               days_to_death  days_to_last  days_survival  diag_age  \
# sample_id
# TCGA-A5-A0G1         3251.0           NaN           3251        67
# TCGA-A5-A0G3            NaN        1079.0           1079        61
# TCGA-A5-A0G5            NaN         790.0            790        73
# TCGA-A5-A0GA          543.0           NaN            543        67
# TCGA-A5-A0GB            NaN         275.0            275        65
#
#                                    race               ethnicity  gender
# sample_id
# TCGA-A5-A0G1                      white  not hispanic or latino  female
# TCGA-A5-A0G3  black or african american                     NaN  female
# TCGA-A5-A0G5  black or african american                     NaN  female
# TCGA-A5-A0GA                      white  not hispanic or latino  female
# TCGA-A5-A0GB                      white                     NaN  female
#              ICDO3site        stage stage_simple  stage_ismeta    grade  \
# sample_id
# TCGA-A5-A0G1     c54.1     stage ia            i             0  grade 3
# TCGA-A5-A0G3     c54.1  stage iiic2          iii             0  grade 3
# TCGA-A5-A0G5     c54.1     stage ib            i             0  grade 3
# TCGA-A5-A0GA     c54.1  stage iiic2          iii             0  grade 3
# TCGA-A5-A0GB     c54.1     stage ib            i             0  grade 3
#
#              grade_simple residual
# sample_id
# TCGA-A5-A0G1   High Grade       r0
# TCGA-A5-A0G3   High Grade       r0
# TCGA-A5-A0G5   High Grade       r0
# TCGA-A5-A0GA   High Grade       r0
# TCGA-A5-A0GB   High Grade       r0
#               days_to_death  days_to_last  days_survival  diag_age   race  \
# sample_id
# TCGA-A5-A0GE            NaN        2717.0           2717        38  asian
# TCGA-A5-A0GI            NaN        1750.0           1750        63  white
# TCGA-A5-A0GX            NaN         924.0            924        53  white
# TCGA-A5-A0G1         3251.0           NaN           3251        67  white
# TCGA-A5-A0GV            NaN         485.0            485        67  white
#
#                            ethnicity  gender
# sample_id
# TCGA-A5-A0GE  not hispanic or latino  female
# TCGA-A5-A0GI  not hispanic or latino  female
# TCGA-A5-A0GX                     NaN  female
# TCGA-A5-A0G1  not hispanic or latino  female
# TCGA-A5-A0GV  not hispanic or latino  female
#              ICDO3site     stage stage_simple  stage_ismeta    grade  \
# sample_id
# TCGA-A5-A0GE     c54.1  stage ia            i             0  grade 2
# TCGA-A5-A0GI     c54.1  stage ia            i             0  grade 2
# TCGA-A5-A0GX     c54.1  stage ia            i             0  grade 2
# TCGA-A5-A0G1     c54.1  stage ia            i             0  grade 3
# TCGA-A5-A0GV     c54.1  stage ia            i             0  grade 1
#
#                  grade_simple residual
# sample_id
# TCGA-A5-A0GE  Low grade (1,2)       r0
# TCGA-A5-A0GI  Low grade (1,2)       r0
# TCGA-A5-A0GX  Low grade (1,2)       r0
# TCGA-A5-A0G1       High Grade       r0
# TCGA-A5-A0GV  Low grade (1,2)       r0

# %% [markdown]
# <a id="select_genes_df"></a>

# %% [markdown]
# ### shorter_df = select_genes_df(spreadsheet_df, gene_select_list) [[top]](#top)
# * spreadsheet_df is a pandas dataframe.
# * "gene_select_list" is a python list.

# %%
spreadsheet_filename = 'gene_samples_1.tsv'
spreadsheet_filename = os.path.join(data_dir, spreadsheet_filename)
spreadsheet_df = pd.read_csv(spreadsheet_filename, sep='\t', index_col=0, header=0)
print(spreadsheet_df.head())

list_file_name = 'gene_samples_1_list.txt'
list_file_name = os.path.join(data_dir, list_file_name)
gene_select_list = mpt.read_a_list_file(list_file_name)
print('\nSelect Genes:', gene_select_list)

short_df = mpt.select_genes_df(spreadsheet_df, gene_select_list)
short_df.head()
# Out:
#               UDDSE     YVRLR     OLHXN     JXCLP     FJFHS     XOOBN  \
# AAASKYLDR  0.583288  0.869696  0.337184  0.777422  0.577689  0.061578
# DYUBIRUER  0.264433  0.653720  0.369235  0.415435  0.085363  0.391574
# GTVXFFTSR  0.410416  0.957459  0.580190  0.316355  0.035407  0.346374
# MPILUWTKU  0.793860  0.637038  0.859623  0.864524  0.112545  0.691766
# BXLOSXZBD  0.481778  0.271875  0.268117  0.785009  0.119547  0.221122
#
#               AXYTF
# AAASKYLDR  0.391267
# DYUBIRUER  0.366597
# GTVXFFTSR  0.932971
# MPILUWTKU  0.989345
# BXLOSXZBD  0.573399
#
# Select Genes: ['BXLOSXZBD', 'IOSIJZWXG', 'SACSCUYCP', 'RXNAMIEOD', 'ARARTETGK', 'AAASKYLDR', 'KONMCBVOY', 'GTVXFFTSR', 'KSMJCSFMM', 'NWGZQVHUL', 'MPILUWTKU', 'RWZKNXXLG', 'ZNUSAPEMV']
#               UDDSE     YVRLR     OLHXN     JXCLP     FJFHS     XOOBN  \
# MPILUWTKU  0.793860  0.637038  0.859623  0.864524  0.112545  0.691766
# KSMJCSFMM  0.599884  0.000296  0.691951  0.392975  0.139808  0.201443
# IOSIJZWXG  0.300951  0.979444  0.977429  0.860223  0.753513  0.475363
# BXLOSXZBD  0.481778  0.271875  0.268117  0.785009  0.119547  0.221122
# AAASKYLDR  0.583288  0.869696  0.337184  0.777422  0.577689  0.061578
#
#               AXYTF
# MPILUWTKU  0.989345
# KSMJCSFMM  0.420018
# IOSIJZWXG  0.426190
# BXLOSXZBD  0.573399
# AAASKYLDR  0.391267

# %% [markdown]
# <a id='merge_df'></a>

# %% [markdown]
# ### merged_df = merge_df(spreadsheet_1_df, spreadsheet_2_df) [[top]](#top)

# %%
spreadsheet_1_df = pd.read_csv(os.path.join(data_dir, 'spreadsheet_One.txt'), sep='\t', header=0, index_col=0)
print(spreadsheet_1_df.head())
spreadsheet_2_df = pd.read_csv(os.path.join(data_dir, 'spreadsheet_Two.txt'), sep='\t', header=0, index_col=0)
print(spreadsheet_2_df.head())

merged_df = mpt.merge_df(spreadsheet_1_df, spreadsheet_2_df)
print(merged_df.head)
# Out:
#               days_to_death  days_to_last  days_survival  diag_age  \
# sample_id
# TCGA-A5-A0G1         3251.0           NaN           3251        67
# TCGA-A5-A0G3            NaN        1079.0           1079        61
# TCGA-A5-A0G5            NaN         790.0            790        73
# TCGA-A5-A0GA          543.0           NaN            543        67
# TCGA-A5-A0GB            NaN         275.0            275        65
#
#                                    race               ethnicity  gender
# sample_id
# TCGA-A5-A0G1                      white  not hispanic or latino  female
# TCGA-A5-A0G3  black or african american                     NaN  female
# TCGA-A5-A0G5  black or african american                     NaN  female
# TCGA-A5-A0GA                      white  not hispanic or latino  female
# TCGA-A5-A0GB                      white                     NaN  female
#              ICDO3site        stage stage_simple  stage_ismeta    grade  \
# sample_id
# TCGA-A5-A0G1     c54.1     stage ia            i             0  grade 3
# TCGA-A5-A0G3     c54.1  stage iiic2          iii             0  grade 3
# TCGA-A5-A0G5     c54.1     stage ib            i             0  grade 3
# TCGA-A5-A0GA     c54.1  stage iiic2          iii             0  grade 3
# TCGA-A5-A0GB     c54.1     stage ib            i             0  grade 3
#
#              grade_simple residual
# sample_id
# TCGA-A5-A0G1   High Grade       r0
# TCGA-A5-A0G3   High Grade       r0
# TCGA-A5-A0G5   High Grade       r0
# TCGA-A5-A0GA   High Grade       r0
# TCGA-A5-A0GB   High Grade       r0
# <bound method NDFrame.head of               days_to_death  days_to_last  days_survival  diag_age  \
# TCGA-A5-A0G1         3251.0           NaN         3251.0      67.0
# TCGA-A5-A0G3            NaN        1079.0         1079.0      61.0
# TCGA-A5-A0G5            NaN         790.0          790.0      73.0
# TCGA-A5-A0GA          543.0           NaN          543.0      67.0
# TCGA-A5-A0GB            NaN         275.0          275.0      65.0
# TCGA-A5-A0GD            NaN           NaN            NaN       NaN
# TCGA-A5-A0GE            NaN        2717.0         2717.0      38.0
# TCGA-A5-A0GG            NaN        2516.0         2516.0      76.0
# TCGA-A5-A0GH            NaN           NaN            NaN       NaN
# TCGA-A5-A0GI            NaN        1750.0         1750.0      63.0
# TCGA-A5-A0GJ            NaN        1447.0         1447.0      44.0
# TCGA-A5-A0GM            NaN           NaN            NaN       NaN
# TCGA-A5-A0GN            NaN        1477.0         1477.0      65.0
# TCGA-A5-A0GP            NaN        1087.0         1087.0      58.0
# TCGA-A5-A0GR            NaN         780.0          780.0      69.0
# TCGA-A5-A0GU            NaN         495.0          495.0      58.0
# TCGA-A5-A0GV            NaN         485.0          485.0      67.0
# TCGA-A5-A0GW            NaN         385.0          385.0      46.0
# TCGA-A5-A0GX            NaN         924.0          924.0      53.0
# TCGA-A5-A0R6            NaN         369.0          369.0      64.0
# TCGA-A5-A0R7            NaN          40.0           40.0      55.0
# TCGA-A5-A0R8            NaN         125.0          125.0      81.0
# TCGA-A5-A0R9            NaN         294.0          294.0      51.0
# TCGA-A5-A0RA            NaN         555.0          555.0      68.0
# TCGA-A5-A0VO            NaN         128.0          128.0      64.0
#
#                                    race               ethnicity  gender  \
# TCGA-A5-A0G1                      white  not hispanic or latino  female
# TCGA-A5-A0G3  black or african american                     NaN  female
# TCGA-A5-A0G5  black or african american                     NaN  female
# TCGA-A5-A0GA                      white  not hispanic or latino  female
# TCGA-A5-A0GB                      white                     NaN  female
# TCGA-A5-A0GD                        NaN                     NaN     NaN
# TCGA-A5-A0GE                      asian  not hispanic or latino  female
# TCGA-A5-A0GG  black or african american  not hispanic or latino  female
# TCGA-A5-A0GH                        NaN                     NaN     NaN
# TCGA-A5-A0GI                      white  not hispanic or latino  female
# TCGA-A5-A0GJ                      white  not hispanic or latino  female
# TCGA-A5-A0GM                        NaN                     NaN     NaN
# TCGA-A5-A0GN                      white  not hispanic or latino  female
# TCGA-A5-A0GP                      asian  not hispanic or latino  female
# TCGA-A5-A0GR  black or african american  not hispanic or latino  female
# TCGA-A5-A0GU                      white                     NaN  female
# TCGA-A5-A0GV                      white  not hispanic or latino  female
# TCGA-A5-A0GW                      asian  not hispanic or latino  female
# TCGA-A5-A0GX                      white                     NaN  female
# TCGA-A5-A0R6                        NaN                     NaN  female
# TCGA-A5-A0R7                      white  not hispanic or latino  female
# TCGA-A5-A0R8                      white  not hispanic or latino  female
# TCGA-A5-A0R9                      white  not hispanic or latino  female
# TCGA-A5-A0RA                      white  not hispanic or latino  female
# TCGA-A5-A0VO                      white  not hispanic or latino  female
#
#              ICDO3site        stage stage_simple  stage_ismeta    grade  \
# TCGA-A5-A0G1     c54.1     stage ia            i           0.0  grade 3
# TCGA-A5-A0G3     c54.1  stage iiic2          iii           0.0  grade 3
# TCGA-A5-A0G5     c54.1     stage ib            i           0.0  grade 3
# TCGA-A5-A0GA     c54.1  stage iiic2          iii           0.0  grade 3
# TCGA-A5-A0GB     c54.1     stage ib            i           0.0  grade 3
# TCGA-A5-A0GD     c54.1     stage ia            i           0.0  grade 2
# TCGA-A5-A0GE     c54.1     stage ia            i           0.0  grade 2
# TCGA-A5-A0GG     c54.1     stage ia            i           0.0  grade 1
# TCGA-A5-A0GH     c54.1     stage ia            i           0.0  grade 3
# TCGA-A5-A0GI     c54.1     stage ia            i           0.0  grade 2
# TCGA-A5-A0GJ     c54.1     stage ia            i           0.0  grade 2
# TCGA-A5-A0GM     c54.1     stage ia            i           0.0  grade 1
# TCGA-A5-A0GN     c54.1     stage ib            i           0.0  grade 1
# TCGA-A5-A0GP       NaN          NaN          NaN           NaN      NaN
# TCGA-A5-A0GR     c54.1     stage ia            i           0.0  grade 2
# TCGA-A5-A0GU     c54.1     stage ia            i           0.0  grade 1
# TCGA-A5-A0GV     c54.1     stage ia            i           0.0  grade 1
# TCGA-A5-A0GW       NaN          NaN          NaN           NaN      NaN
# TCGA-A5-A0GX     c54.1     stage ia            i           0.0  grade 2
# TCGA-A5-A0R6       NaN          NaN          NaN           NaN      NaN
# TCGA-A5-A0R7     c54.1     stage ia            i           0.0  grade 2
# TCGA-A5-A0R8     c54.1     stage ib            i           0.0  grade 2
# TCGA-A5-A0R9       NaN          NaN          NaN           NaN      NaN
# TCGA-A5-A0RA     c54.1     stage ib            i           0.0  grade 2
# TCGA-A5-A0VO       NaN          NaN          NaN           NaN      NaN
#
#                  grade_simple residual
# TCGA-A5-A0G1       High Grade       r0
# TCGA-A5-A0G3       High Grade       r0
# TCGA-A5-A0G5       High Grade       r0
# TCGA-A5-A0GA       High Grade       r0
# TCGA-A5-A0GB       High Grade       r0
# TCGA-A5-A0GD  Low grade (1,2)       r0
# TCGA-A5-A0GE  Low grade (1,2)       r0
# TCGA-A5-A0GG  Low grade (1,2)       r0
# TCGA-A5-A0GH       High Grade       r0
# TCGA-A5-A0GI  Low grade (1,2)       r0
# TCGA-A5-A0GJ  Low grade (1,2)       r0
# TCGA-A5-A0GM  Low grade (1,2)       r0
# TCGA-A5-A0GN  Low grade (1,2)       r0
# TCGA-A5-A0GP              NaN      NaN
# TCGA-A5-A0GR  Low grade (1,2)       r0
# TCGA-A5-A0GU  Low grade (1,2)       r0
# TCGA-A5-A0GV  Low grade (1,2)       r0
# TCGA-A5-A0GW              NaN      NaN
# TCGA-A5-A0GX  Low grade (1,2)       r0
# TCGA-A5-A0R6              NaN      NaN
# TCGA-A5-A0R7  Low grade (1,2)       r0
# TCGA-A5-A0R8  Low grade (1,2)       r0
# TCGA-A5-A0R9              NaN      NaN
# TCGA-A5-A0RA  Low grade (1,2)       r0
# TCGA-A5-A0VO              NaN      NaN  >

# %% [markdown]
# <a id='cluster_statistics_df'></a>

# %% [markdown]
# ### sub_df = cluster_statistics_df(spreadsheet_df, labels_df, centroid_statistic) [[top]](#top)
# * labels_df is the columns selector for the spreadsheet.
# * "centroid_statistic" is either "median", "std" or else: "mean" will be used.
#
# #### Note that if the labels_df is from samples clustering output it requires column naming with pandas read_csv.

# %%
spreadsheet_filename = 'gene_samples_small.tsv'
spreadsheet_filename = os.path.join(data_dir, spreadsheet_filename)
spreadsheet_df = pd.read_csv(spreadsheet_filename, sep='\t', index_col=0, header=0)
print(spreadsheet_df.head())
phenotype_filename = 'gene_samples_small_labels.tsv'
phenotype_filename = os.path.join(data_dir, phenotype_filename)
phenotype_df = pd.read_csv(phenotype_filename, sep='\t', index_col=0, names=['sample','cluster_number'])
print(phenotype_df.head())

centroid_statistic = 'median'
sub_df = mpt.cluster_statistics_df(spreadsheet_df, phenotype_df, centroid_statistic)
sub_df.head()
# Out:
#               SALWI     JUUBB     QGAER     HPEAZ     ZEPZZ     WEVTL  \
# BLAKYEFOI  0.718229  0.682086  0.367574  0.401972  0.798403  0.177443
# YGIMEGNPA  0.489176  0.252566  0.600857  0.221937  0.730823  0.272774
# YZRSYTJXA  0.548217  0.191769  0.423285  0.085875  0.420127  0.047882
# EKKHUWNYK  0.172777  0.910728  0.911077  0.640875  0.950508  0.436302
# CEDCXDTUJ  0.891059  0.266609  0.825600  0.303836  0.094569  0.639886
#
#               CHQAX     SCXTU     FZMUG     YYYZO     JWEIL
# BLAKYEFOI  0.639741  0.735678  0.995612  0.523272  0.289260
# YGIMEGNPA  0.596892  0.122799  0.930491  0.099120  0.138238
# YZRSYTJXA  0.931763  0.433657  0.441884  0.024010  0.671550
# EKKHUWNYK  0.523115  0.590391  0.542579  0.924989  0.283259
# CEDCXDTUJ  0.658354  0.343014  0.909111  0.704618  0.142060
#         cluster_number
# sample
# SALWI                0
# JUUBB                1
# QGAER                2
# HPEAZ                1
# ZEPZZ                2
#                   0         1         2
# BLAKYEFOI  0.581506  0.682086  0.551626
# YGIMEGNPA  0.348006  0.252566  0.436816
# YZRSYTJXA  0.477887  0.441884  0.421706
# EKKHUWNYK  0.724052  0.542579  0.750734
# CEDCXDTUJ  0.681486  0.303836  0.491450

# %% [markdown]
# # Basic transformations: dataframe to dataframe

# %% [markdown]
# <a id='transpose_df'></a>

# %% [markdown]
# ## trans_df = transpose_df(spreadsheet_df) [[top]](#top)

# %%
td_file = 'gene_samples_1.tsv'
t_df = pd.read_csv(os.path.join(data_dir, td_file), sep='\t', index_col=0, header=0)
print(td_file, ':\n', t_df.head())
trans_df = mpt.transpose_df(t_df)
trans_df.head()
# Out:
# gene_samples_1.tsv :
#                UDDSE     YVRLR     OLHXN     JXCLP     FJFHS     XOOBN  \
# AAASKYLDR  0.583288  0.869696  0.337184  0.777422  0.577689  0.061578
# DYUBIRUER  0.264433  0.653720  0.369235  0.415435  0.085363  0.391574
# GTVXFFTSR  0.410416  0.957459  0.580190  0.316355  0.035407  0.346374
# MPILUWTKU  0.793860  0.637038  0.859623  0.864524  0.112545  0.691766
# BXLOSXZBD  0.481778  0.271875  0.268117  0.785009  0.119547  0.221122
#
#               AXYTF
# AAASKYLDR  0.391267
# DYUBIRUER  0.366597
# GTVXFFTSR  0.932971
# MPILUWTKU  0.989345
# BXLOSXZBD  0.573399
#        AAASKYLDR  DYUBIRUER  GTVXFFTSR  MPILUWTKU  BXLOSXZBD  ZNUSAPEMV  \
# UDDSE   0.583288   0.264433   0.410416   0.793860   0.481778   0.604271
# YVRLR   0.869696   0.653720   0.957459   0.637038   0.271875   0.641702
# OLHXN   0.337184   0.369235   0.580190   0.859623   0.268117   0.132654
# JXCLP   0.777422   0.415435   0.316355   0.864524   0.785009   0.601822
# FJFHS   0.577689   0.085363   0.035407   0.112545   0.119547   0.369204
#
#        KSMJCSFMM  QEWEVQWNP  KONMCBVOY  PMAZCXIPY  RWZKNXXLG  ARARTETGK  \
# UDDSE   0.599884   0.260760   0.568654   0.292753   0.886983   0.560096
# YVRLR   0.000296   0.725221   0.182183   0.237518   0.639404   0.603171
# OLHXN   0.691951   0.215147   0.507811   0.586945   0.185245   0.574982
# JXCLP   0.392975   0.588376   0.269978   0.073814   0.386716   0.418067
# FJFHS   0.139808   0.611777   0.925807   0.998298   0.036916   0.765465
#
#        RXNAMIEOD  SACSCUYCP  IOSIJZWXG  NWGZQVHUL
# UDDSE   0.347432   0.898009   0.300951   0.819528
# YVRLR   0.999505   0.840288   0.979444   0.823110
# OLHXN   0.510050   0.716022   0.977429   0.901851
# JXCLP   0.655210   0.612684   0.860223   0.457800
# FJFHS   0.618122   0.449568   0.753513   0.877375

# %% [markdown]
# <a id='abs_df'></a>

# %% [markdown]
# ### abs_val_df = abs_df(spreadsheet_df) [[top]](#top)
# * get the magnitude of a spreadsheet (dataframe)

# %%
td_file = 'gene_samples_1.tsv'
t_df = pd.read_csv(os.path.join(data_dir, td_file), sep='\t', index_col=0, header=0)
print(td_file)
# print(t_df.head())
abs_val_df = mpt.abs_df(t_df)
abs_val_df.head()
# Out:
# gene_samples_1.tsv
#               UDDSE     YVRLR     OLHXN     JXCLP     FJFHS     XOOBN  \
# AAASKYLDR  0.583288  0.869696  0.337184  0.777422  0.577689  0.061578
# DYUBIRUER  0.264433  0.653720  0.369235  0.415435  0.085363  0.391574
# GTVXFFTSR  0.410416  0.957459  0.580190  0.316355  0.035407  0.346374
# MPILUWTKU  0.793860  0.637038  0.859623  0.864524  0.112545  0.691766
# BXLOSXZBD  0.481778  0.271875  0.268117  0.785009  0.119547  0.221122
#
#               AXYTF
# AAASKYLDR  0.391267
# DYUBIRUER  0.366597
# GTVXFFTSR  0.932971
# MPILUWTKU  0.989345
# BXLOSXZBD  0.573399

# %% [markdown]
# <a id='z_transform_df'></a>

# %% [markdown]
# ### z_scored_df = z_transform_df(spreadsheet_df, axis=1) [[top]](#top)

# %%
td_file = 'gene_samples_1.tsv'
t_df = pd.read_csv(os.path.join(data_dir, td_file), sep='\t', index_col=0, header=0)
print(td_file, ':\n', t_df.head())
z_score_df = mpt.z_transform_df(t_df, axis=1)
z_score_df.head()
# Out:
# gene_samples_1.tsv :
#                UDDSE     YVRLR     OLHXN     JXCLP     FJFHS     XOOBN  \
# AAASKYLDR  0.583288  0.869696  0.337184  0.777422  0.577689  0.061578
# DYUBIRUER  0.264433  0.653720  0.369235  0.415435  0.085363  0.391574
# GTVXFFTSR  0.410416  0.957459  0.580190  0.316355  0.035407  0.346374
# MPILUWTKU  0.793860  0.637038  0.859623  0.864524  0.112545  0.691766
# BXLOSXZBD  0.481778  0.271875  0.268117  0.785009  0.119547  0.221122
#
#               AXYTF
# AAASKYLDR  0.391267
# DYUBIRUER  0.366597
# GTVXFFTSR  0.932971
# MPILUWTKU  0.989345
# BXLOSXZBD  0.573399
#               UDDSE     YVRLR     OLHXN     JXCLP     FJFHS     XOOBN  \
# AAASKYLDR  0.583288  0.869696  0.337184  0.777422  0.577689  0.061578
# DYUBIRUER  0.264433  0.653720  0.369235  0.415435  0.085363  0.391574
# GTVXFFTSR  0.410416  0.957459  0.580190  0.316355  0.035407  0.346374
# MPILUWTKU  0.793860  0.637038  0.859623  0.864524  0.112545  0.691766
# BXLOSXZBD  0.481778  0.271875  0.268117  0.785009  0.119547  0.221122
#
#               AXYTF
# AAASKYLDR  0.391267
# DYUBIRUER  0.366597
# GTVXFFTSR  0.932971
# MPILUWTKU  0.989345
# BXLOSXZBD  0.573399

# %% [markdown]
# <a id='log_transform_df'></a>

# %% [markdown]
# ### log_df = log_transform_df(spreadsheet_df, log_base=np.exp(1), log_offset=0) [[top]](#top)
# * log_base default is the natural log
# * log_offset default is 0 (none)

# %%
td_file = 'gene_samples_1.tsv'
t_df = pd.read_csv(os.path.join(data_dir, td_file), sep='\t', index_col=0, header=0)
print(td_file, ':\n', t_df.head())

log_df = mpt.log_transform_df(t_df)
log_df.head()
# Out:
# gene_samples_1.tsv :
#                UDDSE     YVRLR     OLHXN     JXCLP     FJFHS     XOOBN  \
# AAASKYLDR  0.583288  0.869696  0.337184  0.777422  0.577689  0.061578
# DYUBIRUER  0.264433  0.653720  0.369235  0.415435  0.085363  0.391574
# GTVXFFTSR  0.410416  0.957459  0.580190  0.316355  0.035407  0.346374
# MPILUWTKU  0.793860  0.637038  0.859623  0.864524  0.112545  0.691766
# BXLOSXZBD  0.481778  0.271875  0.268117  0.785009  0.119547  0.221122
#
#               AXYTF
# AAASKYLDR  0.391267
# DYUBIRUER  0.366597
# GTVXFFTSR  0.932971
# MPILUWTKU  0.989345
# BXLOSXZBD  0.573399
#               UDDSE     YVRLR     OLHXN     JXCLP     FJFHS     XOOBN  \
# AAASKYLDR  0.583288  0.869696  0.337184  0.777422  0.577689  0.061578
# DYUBIRUER  0.264433  0.653720  0.369235  0.415435  0.085363  0.391574
# GTVXFFTSR  0.410416  0.957459  0.580190  0.316355  0.035407  0.346374
# MPILUWTKU  0.793860  0.637038  0.859623  0.864524  0.112545  0.691766
# BXLOSXZBD  0.481778  0.271875  0.268117  0.785009  0.119547  0.221122
#
#               AXYTF
# AAASKYLDR  0.391267
# DYUBIRUER  0.366597
# GTVXFFTSR  0.932971
# MPILUWTKU  0.989345
# BXLOSXZBD  0.573399

# %% [markdown]
# <a id='threshold_df'></a>

# %% [markdown]
# ### thresh_df = threshold_df(spreadsheet_df, cut_off, sub_val, scope) [[top]](#top)
# * Get a dataframe with values below "cut_off" set to "sub_val" unless "scope" is input as anything EXCEPT "SUB_BELOW"

# %%
#                           Choose a features x samples spreadsheet:
td_file = 'gene_samples_1.tsv'
t_df = pd.read_csv(os.path.join(data_dir, td_file), sep='\t', index_col=0, header=0)
# print(td_file, ':\n', t_df.head())
threshold = 0.3
threshold_df = mpt.threshold_df(t_df, cut_off=threshold, sub_val=0, scope='SUB_BELOW')
threshold_df.head()
# Out:
#               UDDSE     YVRLR     OLHXN     JXCLP     FJFHS     XOOBN  \
# AAASKYLDR  0.583288  0.869696  0.337184  0.777422  0.577689  0.000000
# DYUBIRUER  0.000000  0.653720  0.369235  0.415435  0.000000  0.391574
# GTVXFFTSR  0.410416  0.957459  0.580190  0.316355  0.000000  0.346374
# MPILUWTKU  0.793860  0.637038  0.859623  0.864524  0.000000  0.691766
# BXLOSXZBD  0.481778  0.000000  0.000000  0.785009  0.000000  0.000000
#
#               AXYTF
# AAASKYLDR  0.391267
# DYUBIRUER  0.366597
# GTVXFFTSR  0.932971
# MPILUWTKU  0.989345
# BXLOSXZBD  0.573399

# %% [markdown]
# <a id='stats_df'></a>

# %% [markdown]
# ### report_df = stats_df(t_df, stats_function=stat, direction_reference=dr)  [[top]](#top)
# * get a dataframe of requested stat as specified by the function and direction.
# * function signiture:
#     * stats_dataframe = stats_df(input_df, stats_function, direction_reference)
#     * output will be a dataframe even if it only contains one value
# * possible functions are: ['min', 'max', 'mean', 'median', 'variation', 'std_deviation', 'sum']
# * possible directions are: ['columns', 'rows', 'all']

# %%
#                           Choose a features x samples spreadsheet:
td_file = 'gene_samples_1.tsv'
t_df = pd.read_csv(os.path.join(data_dir, td_file), sep='\t', index_col=0, header=0)
print(td_file, ':\n', t_df.head())

stat_f_list = ['min', 'max', 'mean', 'median', 'variation', 'std_deviation', 'sum']
dir_list = ['columns', 'rows', 'all']
for stat in stat_f_list:
    for dr in dir_list:
        print('\n\n\t\tstats_function =', stat, ': direction_reference =', dr)
        ho_df = mpt.stats_df(t_df, stats_function=stat, direction_reference=dr)
        print(ho_df)
# Out:
# gene_samples_1.tsv :
#                UDDSE     YVRLR     OLHXN     JXCLP     FJFHS     XOOBN  \
# AAASKYLDR  0.583288  0.869696  0.337184  0.777422  0.577689  0.061578
# DYUBIRUER  0.264433  0.653720  0.369235  0.415435  0.085363  0.391574
# GTVXFFTSR  0.410416  0.957459  0.580190  0.316355  0.035407  0.346374
# MPILUWTKU  0.793860  0.637038  0.859623  0.864524  0.112545  0.691766
# BXLOSXZBD  0.481778  0.271875  0.268117  0.785009  0.119547  0.221122
#
#               AXYTF
# AAASKYLDR  0.391267
# DYUBIRUER  0.366597
# GTVXFFTSR  0.932971
# MPILUWTKU  0.989345
# BXLOSXZBD  0.573399
#
#
# 		stats_function = min : direction_reference = columns
#        UDDSE     YVRLR     OLHXN     JXCLP     FJFHS     XOOBN     AXYTF
# min  0.26076  0.000296  0.132654  0.073814  0.035407  0.017905  0.002284
#
#
# 		stats_function = min : direction_reference = rows
#                 min
# AAASKYLDR  0.061578
# DYUBIRUER  0.085363
# GTVXFFTSR  0.035407
# MPILUWTKU  0.112545
# BXLOSXZBD  0.119547
# ZNUSAPEMV  0.002284
# KSMJCSFMM  0.000296
# QEWEVQWNP  0.083369
# KONMCBVOY  0.046360
# PMAZCXIPY  0.073814
# RWZKNXXLG  0.036916
# ARARTETGK  0.026542
# RXNAMIEOD  0.074257
# SACSCUYCP  0.449568
# IOSIJZWXG  0.300951
# NWGZQVHUL  0.017905
#
#
# 		stats_function = min : direction_reference = all
#           min
# min  0.000296
#
#
# 		stats_function = max : direction_reference = columns
#         UDDSE     YVRLR     OLHXN     JXCLP     FJFHS     XOOBN     AXYTF
# max  0.898009  0.999505  0.977429  0.864524  0.998298  0.967999  0.989345
#
#
# 		stats_function = max : direction_reference = rows
#                 max
# AAASKYLDR  0.869696
# DYUBIRUER  0.653720
# GTVXFFTSR  0.957459
# MPILUWTKU  0.989345
# BXLOSXZBD  0.785009
# ZNUSAPEMV  0.641702
# KSMJCSFMM  0.691951
# QEWEVQWNP  0.725221
# KONMCBVOY  0.925807
# PMAZCXIPY  0.998298
# RWZKNXXLG  0.967999
# ARARTETGK  0.765465
# RXNAMIEOD  0.999505
# SACSCUYCP  0.906096
# IOSIJZWXG  0.979444
# NWGZQVHUL  0.901851
#
#
# 		stats_function = max : direction_reference = all
#           max
# max  0.999505
#
#
# 		stats_function = mean : direction_reference = columns
#          UDDSE     YVRLR     OLHXN     JXCLP     FJFHS    XOOBN     AXYTF
# mean  0.542068  0.628852  0.525902  0.529776  0.467275  0.38498  0.524053
#
#
# 		stats_function = mean : direction_reference = rows
#                mean
# AAASKYLDR  0.514018
# DYUBIRUER  0.363765
# GTVXFFTSR  0.511310
# MPILUWTKU  0.706957
# BXLOSXZBD  0.388692
# ZNUSAPEMV  0.381212
# KSMJCSFMM  0.349482
# QEWEVQWNP  0.385913
# KONMCBVOY  0.469014
# PMAZCXIPY  0.483353
# RWZKNXXLG  0.552355
# ARARTETGK  0.487744
# RXNAMIEOD  0.533832
# SACSCUYCP  0.748621
# IOSIJZWXG  0.681873
# NWGZQVHUL  0.677070
#
#
# 		stats_function = mean : direction_reference = all
#           mean
# mean  0.514701
#
#
# 		stats_function = median : direction_reference = columns
#            UDDSE     YVRLR     OLHXN     JXCLP     FJFHS    XOOBN     AXYTF
# median  0.564375  0.647711  0.542516  0.523088  0.513628  0.33146  0.499794
#
#
# 		stats_function = median : direction_reference = rows
#              median
# AAASKYLDR  0.577689
# DYUBIRUER  0.369235
# GTVXFFTSR  0.410416
# MPILUWTKU  0.793860
# BXLOSXZBD  0.271875
# ZNUSAPEMV  0.369204
# KSMJCSFMM  0.392975
# QEWEVQWNP  0.260760
# KONMCBVOY  0.507811
# PMAZCXIPY  0.300670
# RWZKNXXLG  0.639404
# ARARTETGK  0.560096
# RXNAMIEOD  0.532249
# SACSCUYCP  0.817684
# IOSIJZWXG  0.753513
# NWGZQVHUL  0.823110
#
#
# 		stats_function = median : direction_reference = all
#           median
# median  0.546172
#
#
# 		stats_function = variation : direction_reference = columns
#               UDDSE     YVRLR     OLHXN     JXCLP     FJFHS     XOOBN  \
# variation  0.048756  0.092987  0.068256  0.051321  0.117906  0.079877
#
#               AXYTF
# variation  0.120858
#
#
# 		stats_function = variation : direction_reference = rows
#            variation
# AAASKYLDR   0.075963
# DYUBIRUER   0.029155
# GTVXFFTSR   0.113911
# MPILUWTKU   0.082312
# BXLOSXZBD   0.054759
# ZNUSAPEMV   0.062662
# KSMJCSFMM   0.062444
# QEWEVQWNP   0.062019
# KONMCBVOY   0.103128
# PMAZCXIPY   0.123659
# RWZKNXXLG   0.127444
# ARARTETGK   0.053556
# RXNAMIEOD   0.080868
# SACSCUYCP   0.028210
# IOSIJZWXG   0.077661
# NWGZQVHUL   0.107004
#
#
# 		stats_function = variation : direction_reference = all
#            variation
# variation    0.08243
#
#
# 		stats_function = std_deviation : direction_reference = columns
#                   UDDSE     YVRLR     OLHXN     JXCLP     FJFHS     XOOBN  \
# std_deviation  0.220809  0.304938  0.261258  0.226541  0.343374  0.282625
#
#                   AXYTF
# std_deviation  0.347647
#
#
# 		stats_function = std_deviation : direction_reference = rows
#            std_deviation
# AAASKYLDR       0.275615
# DYUBIRUER       0.170748
# GTVXFFTSR       0.337507
# MPILUWTKU       0.286901
# BXLOSXZBD       0.234006
# ZNUSAPEMV       0.250324
# KSMJCSFMM       0.249887
# QEWEVQWNP       0.249035
# KONMCBVOY       0.321135
# PMAZCXIPY       0.351653
# RWZKNXXLG       0.356992
# ARARTETGK       0.231422
# RXNAMIEOD       0.284374
# SACSCUYCP       0.167959
# IOSIJZWXG       0.278677
# NWGZQVHUL       0.327115
#
#
# 		stats_function = std_deviation : direction_reference = all
#                std_deviation
# std_deviation       0.287106
#
#
# 		stats_function = sum : direction_reference = columns
#         UDDSE     YVRLR     OLHXN     JXCLP     FJFHS     XOOBN     AXYTF
# sum  8.673096  10.06163  8.414435  8.476411  7.476406  6.159675  8.384841
#
#
# 		stats_function = sum : direction_reference = rows
#                 sum
# AAASKYLDR  3.598123
# DYUBIRUER  2.546357
# GTVXFFTSR  3.579173
# MPILUWTKU  4.948701
# BXLOSXZBD  2.720846
# ZNUSAPEMV  2.668483
# KSMJCSFMM  2.446375
# QEWEVQWNP  2.701394
# KONMCBVOY  3.283095
# PMAZCXIPY  3.383472
# RWZKNXXLG  3.866484
# ARARTETGK  3.414211
# RXNAMIEOD  3.736825
# SACSCUYCP  5.240350
# IOSIJZWXG  4.773113
# NWGZQVHUL  4.739490
#
#
# 		stats_function = sum : direction_reference = all
#            sum
# sum  57.646493

# %% [markdown]
# # Utilities:

# %% [markdown]
# <a id="write_transform_df"></a>

# %% [markdown]
# ### write_transform_df(spreadsheet_df, spreadsheet_file_name, transform_name, results_directory) [[Top]](#top)
# * construct the filename and write the spreadsheet

# %%
spreadsheet_name_full_path = os.path.join(data_dir, 'gene_samples_1.tsv')
transform_name = 'transformation_X'

spreadsheet_df = pd.read_csv(spreadsheet_name_full_path, sep='\t', index_col=0, header=0)

mpt.write_transform_df(spreadsheet_df, spreadsheet_name_full_path, transform_name, results_dir)
os.listdir(results_dir)
# Out:
# ['gene_samples_1_transformation_X_Mon_11_Sep_2017_08_10_10.501739025.tsv']

# %% [markdown]
# <a id='read_a_list_file'></a>

# %% [markdown]
# ## python_dakine_list = read_a_list_file(list_file_name) [[top]](#top)

# %%
list_file_name = 'gene_samples_1_list.txt'
list_file_name = os.path.join(data_dir, list_file_name)

some_list = mpt.read_a_list_file(list_file_name)
for list_name in some_list:
    print(list_name)
# Out:
# BXLOSXZBD
# IOSIJZWXG
# SACSCUYCP
# RXNAMIEOD
# ARARTETGK
# AAASKYLDR
# KONMCBVOY
# GTVXFFTSR
# KSMJCSFMM
# NWGZQVHUL
# MPILUWTKU
# RWZKNXXLG
# ZNUSAPEMV

# %% [markdown]
# <a id='get_outfile_name'></a>

# %% [markdown]
# ## full_file_name = get_outfile_name(write_dir, file_name, xform_name, file_ext) [[top]](#top)

# %%
destination_dir = '../../tmp_result'
spreadsheet_file_name = 'maybe_fileWasXformed'
transform_name = 'transformation_X'
full_file_name = mpt.get_outfile_name(destination_dir, spreadsheet_file_name, transform_name, file_ext='.tsv')
print(full_file_name)
# Out:
# ../../tmp_result/maybe_fileWasXformed_transformation_X_Mon_11_Sep_2017_08_10_10.519591093..tsv
